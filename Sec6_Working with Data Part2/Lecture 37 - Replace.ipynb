# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
ser1= Series([1,2,3,4,1,2,3,4])

# %%
ser1.replace(to_replace=1,value=np.nan)  # ser1.replace(1,np.nan) returns the same result
# Out:
# 0    NaN
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    2.0
# 6    3.0
# 7    4.0
# dtype: float64

# %%
ser1.replace([1,4],[100,400])
# Out:
# 0    100
# 1      2
# 2      3
# 3    400
# 4    100
# 5      2
# 6      3
# 7    400
# dtype: int64

# %%
ser1.replace({4:np.nan})
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    1.0
# 5    2.0
# 6    3.0
# 7    NaN
# dtype: float64
