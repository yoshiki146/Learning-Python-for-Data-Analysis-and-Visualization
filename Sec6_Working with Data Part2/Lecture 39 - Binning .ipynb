# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
years = [1990,1991,1992,2008,2012,2015,1987,1969,2013,2008,1999]
decade_bins = [1960,1970,1980,1990,2000,2010,2020]

# %%
# category objects
decade_cat= pd.cut(years,decade_bins)
decade_cat
# Out:
# [(1980, 1990], (1990, 2000], (1990, 2000], (2000, 2010], (2010, 2020], ..., (1980, 1990], (1960, 1970], (2010, 2020], (2000, 2010], (1990, 2000]]
# Length: 11
# Categories (6, object): [(1960, 1970] < (1970, 1980] < (1980, 1990] < (1990, 2000] < (2000, 2010] < (2010, 2020]]

# %%
decade_cat.categories
# Out:
# Index(['(1960, 1970]', '(1970, 1980]', '(1980, 1990]', '(1990, 2000]',
#        '(2000, 2010]', '(2010, 2020]'],
#       dtype='object')

# %%
# check the value counts in each category
pd.value_counts(decade_cat)
# Out:
# (2010, 2020]    3
# (1990, 2000]    3
# (2000, 2010]    2
# (1980, 1990]    2
# (1960, 1970]    1
# (1970, 1980]    0
# dtype: int64

# %%
pd.cut(years,bins=2,precision=1)   #`bins` specifies how many categories you want
# Out:
# [(1969, 1992], (1969, 1992], (1969, 1992], (1992, 2015], (1992, 2015], ..., (1969, 1992], (1969, 1992], (1992, 2015], (1992, 2015], (1992, 2015]]
# Length: 11
# Categories (2, object): [(1969, 1992] < (1992, 2015]]
