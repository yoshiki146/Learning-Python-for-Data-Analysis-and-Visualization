# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
dframe=DataFrame({"key1":["A"]*2+["B"]*3,
                                     "key2":[2,2,2,3,3]})
dframe
# Out:
#   key1  key2
# 0    A     2
# 1    A     2
# 2    B     2
# 3    B     3
# 4    B     3

# %%
dframe.duplicated() # returns True if n-th row is the duplication of n-1
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
dframe.drop_duplicates()
# Out:
#   key1  key2
# 0    A     2
# 2    B     2
# 3    B     3

# %%
dframe.drop_duplicates(["key1"]) # drops rows with the same value w.r.t. key1
# Out:
#   key1  key2
# 0    A     2
# 2    B     2

# %%
dframe
# Out:
#   key1  key2
# 0    A     2
# 1    A     2
# 2    B     2
# 3    B     3
# 4    B     3

# %%
dframe.drop_duplicates(["key1"],keep="last") # takes the last row
# Out:
#   key1  key2
# 1    A     2
# 4    B     3
